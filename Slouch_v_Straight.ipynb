# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagilardini/UCLA_M119/blob/main/Slouch_v_Straight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Align **

# %%
from google.colab import drive
import scipy.io as sio
#mount your drive so google colab can access files in it
drive.mount('/content/drive')
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#load that data set stored in test_data_straight1.mat
dir = "/content/drive/MyDrive/UCLA_ACADEMIC/M119/Align/DATA/"

data1 = pd.read_csv(dir + 'test_data_slouch1.csv')
data2 = pd.read_csv(dir + 'test_data_slouch2.csv')
data3 = pd.read_csv(dir + 'test_data_slouch3.csv')
data4 = pd.read_csv(dir + 'test_data_slouch4.csv')
data5 = pd.read_csv(dir + 'test_data_slouch5.csv')

data6 = pd.read_csv(dir + 'test_data_straight1.csv')
data7 = pd.read_csv(dir + 'test_data_straight2.csv')
data8 = pd.read_csv(dir + 'test_data_straight3.csv')
data9 = pd.read_csv(dir + 'test_data_straight4.csv')
data10 = pd.read_csv(dir + 'test_data_straight5.csv')

# %%
print(data1.keys())

length1 = data1.shape[0]
length2 = data2.shape[0]
length3 = data3.shape[0]
length4 = data4.shape[0]
length5 = data5.shape[0]

t1 = np.linspace(0,1,length1)
t2 = np.linspace(0,1,length2)
t3 = np.linspace(0,1,length3)
t4 = np.linspace(0,1,length4)
t5 = np.linspace(0,1,length5)



Ax1 = data1['Ax']
Ay1 = data1[' Ay']
Az1 = data1[' Az']
Gx1 = data1[' Gx']
Gy1 = data1[' Gy']
Gz1 = data1[' Gz']

Ax2, Ay2, Az2, Gx2, Gy2, Gz2 = data2['Ax'], data2[' Ay'], data2[' Az'], data2[' Gx'], data2[' Gy'], data2[' Gz']
Ax3, Ay3, Az3, Gx3, Gy3, Gz3 = data3['Ax'], data3[' Ay'], data3[' Az'], data3[' Gx'], data3[' Gy'], data3[' Gz']
Ax4, Ay4, Az4, Gx4, Gy4, Gz4 = data4['Ax'], data4[' Ay'], data4[' Az'], data4[' Gx'], data4[' Gy'], data4[' Gz']
Ax5, Ay5, Az5, Gx5, Gy5, Gz5 = data5['Ax'], data5[' Ay'], data5[' Az'], data5[' Gx'], data5[' Gy'], data5[' Gz']
# Out:
# Index(['Ax', ' Ay', ' Az', ' Gx', ' Gy', ' Gz'], dtype='object')

# %%
#plot 
fig, ax = plt.subplots(2,3, figsize=(25,20))



ax[0,0].plot(t1, Ax1)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t1, Ay1)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t1, Ay1)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t1, Gx1)
ax[1,0].set_title("Gx")
ax[1,0].grid()
ax[1,1].plot(t1, Gy1)
ax[1,1].set_title("Gy")
ax[1,1].grid()
fig.tight_layout(pad=4.0)
ax[1,2].plot(t1, Gz1)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-10,30]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()

# %%
#plot 
fig, ax = plt.subplots(2,3, figsize=(25,20))

ax[0,0].plot(t2, Ax2)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t2, Ay2)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t2, Ay2)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t2, Gx2)
ax[1,0].set_title("Gx")
ax[1,0].grid()
ax[1,1].plot(t2, Gy2)
ax[1,1].set_title("Gy")
ax[1,1].grid()
fig.tight_layout(pad=4.0)
ax[1,2].plot(t2, Gz2)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-10,30]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()

# %%
#plot 
fig, ax = plt.subplots(2,3, figsize=(25,20))

ax[0,0].plot(t3, Ax3)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t3, Ay3)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t3, Ay3)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t3, Gx3)
ax[1,0].set_title("Gx")
ax[1,0].grid()
ax[1,1].plot(t3, Gy3)
ax[1,1].set_title("Gy")
ax[1,1].grid()
fig.tight_layout(pad=4.0)
ax[1,2].plot(t3, Gz3)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-10,30]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()

# %%
#plot 
fig, ax = plt.subplots(2,3, figsize=(25,20))

ax[0,0].plot(t4, Ax4)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t4, Ay4)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t4, Ay4)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t4, Gx4)
ax[1,0].set_title("Gx")
ax[1,0].grid()
ax[1,1].plot(t4, Gy4)
ax[1,1].set_title("Gy")
ax[1,1].grid()
fig.tight_layout(pad=4.0)
ax[1,2].plot(t4, Gz4)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-10,30]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()

# %%
#plot 
fig, ax = plt.subplots(2,3, figsize=(25,20))

ax[0,0].plot(t5, Ax5)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t5, Ay5)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t5, Ay5)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t5, Gx5)
ax[1,0].set_title("Gx")
ax[1,0].grid()

ax[1,1].plot(t5, Gy5)
ax[1,1].set_title("Gy")
ax[1,1].grid()

fig.tight_layout(pad=4.0)

ax[1,2].plot(t5, Gz5)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-10,30]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()

# %%
#sharey = False
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True,figsize=(10,5))

axes[0].plot(t1, Ax1, 'b', label = "Ax1")
axes[0].plot(t2, Ax2, 'r', label = "Ax2")
axes[0].plot(t3, Ax3, 'm', label = "Ax3")
axes[0].plot(t4, Ax4, 'g', label = "Ax4")
axes[0].plot(t5, Ax5, 'c', label = "Ax5")

axes[1].plot(t1, Gy1, 'b', label = "Gy1")
axes[1].plot(t2, Gy2, 'r', label = "Gy2")
axes[1].plot(t3, Gy3, 'm', label = "Gy3")
axes[1].plot(t4, Gy4, 'g', label = "Gy4")
axes[1].plot(t5, Gy5, 'c', label = "Gy5")


axes[0].title.set_text('Ax')
axes[1].title.set_text('Gy')
axes[0].legend()
axes[1].legend()




plt.grid()

# %%
# bend data analysis 

data11 = pd.read_csv(dir + 'test_data_bendbackslouch1.csv')
data12 = pd.read_csv(dir + 'test_data_bendbackstraight1.csv')
data13 = pd.read_csv(dir + 'test_data_bendslouch1.csv')
data14 = pd.read_csv(dir + 'test_data_bendstraight1.csv')

length11 = data11.shape[0]
length12 = data12.shape[0]
length13 = data13.shape[0]
length14 = data14.shape[0]

t11 = np.linspace(0,1,length11)
t12 = np.linspace(0,1,length12)
t13 = np.linspace(0,1,length13)
t14 = np.linspace(0,1,length14)

Ax11, Ay11, Az11, Gx11, Gy11, Gz11 = data11['Ax'], data11[' Ay'], data11[' Az'], data11[' Gx'], data11[' Gy'], data11[' Gz']
Ax12, Ay12, Az12, Gx12, Gy12, Gz12 = data12['Ax'], data12[' Ay'], data12[' Az'], data12[' Gx'], data12[' Gy'], data12[' Gz']
Ax13, Ay13, Az13, Gx13, Gy13, Gz13 = data13['Ax'], data13[' Ay'], data13[' Az'], data13[' Gx'], data13[' Gy'], data13[' Gz']
Ax14, Ay14, Az14, Gx14, Gy14, Gz14 = data14['Ax'], data14[' Ay'], data14[' Az'], data14[' Gx'], data14[' Gy'], data14[' Gz']

# %%
#plot bend back slouch1
fig, ax = plt.subplots(2,3, figsize=(25,20))
fig.suptitle("Bend Back Slouch", fontsize=16)


ax[0,0].plot(t11, Ax11)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t11, Ay11)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t11, Ay11)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t11, Gx11)
ax[1,0].set_title("Gx")
ax[1,0].grid()
ax[1,1].plot(t11, Gy11)
ax[1,1].set_title("Gy")
ax[1,1].grid()
fig.tight_layout(pad=4.0)
ax[1,2].plot(t11, Gz11)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-60,60]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()

# %%
#plot bend back slouch1
fig, ax = plt.subplots(2,3, figsize=(25,20))
fig.suptitle("Bend Back Straight", fontsize=16)


ax[0,0].plot(t12, Ax12)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t12, Ay12)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t12, Ay12)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t12, Gx12)
ax[1,0].set_title("Gx")
ax[1,0].grid()
ax[1,1].plot(t12, Gy12)
ax[1,1].set_title("Gy")
ax[1,1].grid()
fig.tight_layout(pad=4.0)
ax[1,2].plot(t12, Gz12)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-60,60]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()

# %%
#plot bend back slouch1
fig, ax = plt.subplots(2,3, figsize=(25,20))
fig.suptitle("Bend Slouch", fontsize=16)


ax[0,0].plot(t13, Ax13)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t13, Ay13)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t13, Ay13)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t13, Gx13)
ax[1,0].set_title("Gx")
ax[1,0].grid()
ax[1,1].plot(t13, Gy13)
ax[1,1].set_title("Gy")
ax[1,1].grid()
fig.tight_layout(pad=4.0)
ax[1,2].plot(t13, Gz13)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-60,60]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()

# %%
#plot bend back slouch1
fig, ax = plt.subplots(2,3, figsize=(25,20))
fig.suptitle("Bend Straight", fontsize=16)


ax[0,0].plot(t14, Ax14)
ax[0,0].set_title("Ax")
ax[0,0].grid()

#ax[0,0].set_ylim([-20,20]) 

ax[0,1].plot(t14, Ay14)
ax[0,1].set_title("Ay")
ax[0,1].grid()

ax[0,2].plot(t14, Ay14)
ax[0,2].set_title("Ay")
ax[0,2].grid()

ax[1,0].plot(t14, Gx14)
ax[1,0].set_title("Gx")
ax[1,0].grid()
ax[1,1].plot(t14, Gy14)
ax[1,1].set_title("Gy")
ax[1,1].grid()
fig.tight_layout(pad=4.0)
ax[1,2].plot(t14, Gz14)
ax[1,2].set_title("Gz")
ax[1,2].grid()

for i in range(3):
    ax[1,i].set_ylim([-60,60]) 

for j in range(3):
    ax[0,j].set_ylim([-1,1]) 

plt.show()
